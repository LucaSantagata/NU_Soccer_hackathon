# %%
import os, re, json
import pandas as pd
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)
pd.set_option("display.max_colwidth",None)
from pathlib import Path
from glob import glob
from pathlib import Path
from tqdm import tqdm

# %%
# ----------------------------
# CONFIG
# ----------------------------
SKIP_TYPES = {"Half End", "Half Start", "Referee Ball Drop", "Starting XI"}

# ----------------------------
# Helpers
# ----------------------------
def parse_match_id_from_filename(path: str) -> str:
    m = re.search(r"_([0-9]+)\.json$", os.path.basename(str(path)))
    return m.group(1) if m else "unknown"

def norm_type_name(tname: str) -> str:
    return "Ball Receipt" if tname == "Ball Receipt*" else tname

# ----------------------------
# Core logic
# ----------------------------
def build_possession_sequences(events):
    """
    Build sequences segmented by ev["possession"].
    Keep ONLY events where team.id == possession_team.id.
    """
    sequences = {}
    id_to_name = {}

    current_possession = None
    current_team_id = None
    buffer_words, buffer_players = [], []

    def flush_run():
        nonlocal buffer_words, buffer_players, current_possession, current_team_id
        if not buffer_words or current_team_id is None or current_possession is None:
            return
        sequences.setdefault(current_team_id, []).append({
            "words": buffer_words[:],
            "players": buffer_players[:],
            "possession": int(current_possession),
        })
        buffer_words, buffer_players = [], []

    for ev in events:
        poss_num = ev.get("possession")
        if poss_num is None:
            continue

        poss_team = ev.get("possession_team") or {}
        team = ev.get("team") or {}

        poss_team_id = poss_team.get("id")
        poss_team_name = poss_team.get("name")
        team_id = team.get("id")
        team_name = team.get("name")

        if poss_team_id is None or poss_team_name is None or team_id is None or team_name is None:
            continue

        # FILTER: keep only events attributed to the team in possession
        if team_id != poss_team_id:
            continue

        id_to_name[poss_team_id] = poss_team_name

        t = ev.get("type")
        tname = t.get("name") if isinstance(t, dict) else None
        if not tname:
            continue
        tname = norm_type_name(tname)

        if tname in SKIP_TYPES:
            continue

        player_name = (ev.get("player") or {}).get("name") or "Unknown"

        # start
        if current_possession is None:
            current_possession = poss_num
            current_team_id = poss_team_id
            buffer_words.append(tname)
            buffer_players.append(player_name)
            continue

        # possession (or team) switch
        if poss_num != current_possession or poss_team_id != current_team_id:
            flush_run()
            current_possession = poss_num
            current_team_id = poss_team_id

        buffer_words.append(tname)
        buffer_players.append(player_name)

    flush_run()
    return sequences, id_to_name

def runs_to_df(runs, match_id, team_name):
    rows = []
    for run in runs:
        words = run["words"]
        players = run["players"]
        poss_num = run["possession"]

        if not words:
            continue

        if len(players) < len(words):
            players = players + ["Unknown"] * (len(words) - len(players))

        rows.append({
            "words": "-".join(words),
            "possession": poss_num,        # 👈 colonna separata
            "word_players": "-".join(players),
            "match_id": match_id,
            "team_name": team_name,
        })

    return pd.DataFrame(
        rows,
        columns=["words", "possession", "word_players", "match_id", "team_name"]
    )

def process_match_file(path):
    with open(path, "r", encoding="utf-8") as f:
        data = json.load(f)

    events = data if isinstance(data, list) else data.get("events", [])
    if not events:
        print(f"Nessun evento trovato in {path}")
        return None, None

    sequences, id_to_name = build_possession_sequences(events)
    match_id = parse_match_id_from_filename(path)

    dfs = []
    for team_id, runs in sequences.items():
        team_name = id_to_name.get(team_id, f"Team{team_id}")
        dfs.append(runs_to_df(runs, match_id, team_name))

    if len(dfs) == 2:
        return dfs[0], dfs[1]
    elif len(dfs) == 1:
        return dfs[0], None
    else:
        return None, None

# %%
df_team1, df_team2 = process_match_file("AC Milan_AS Roma_3945135.json")

# %%
df_team1
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                       words  \
# 0                                                                                                                                                                                                                                                                                                                                                               Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                 Pass-Ball Receipt-Carry-Pass-Ball Receipt
# 2                                                                                                                                                                                                                                                                     Pass-Ball Receipt-Carry-Foul Won-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Pressure-Ball Receipt
# 3                                                                                                                                                                            Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Shot
# 4                                                                                                                                                                                                                                                                                                                                                                                                                     Pass-Ball Receipt-Pass-Ball Receipt-Pass-Ball Receipt
# 5                                                                                                                                                                                                                                                                                                                           Goal Keeper-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt
# 6                                                                                                                                                                                                                                                                                                                                                                Block-Ball Recovery-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Foul Won
# 7                                                                                                                                                                                                                                                                                                                                                                            Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Shot
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                          Ball Recovery-Carry-Dispossessed
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                      Interception-Carry-Pass-Ball Receipt
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                      Pass-Ball Receipt-Pass-Ball Receipt
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                        Duel-Ball Recovery-Carry-Foul Won
# 12                                                                                                                                                                                                                                                                                                                                                        Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Block
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                             Ball Recovery-Carry-Foul Won
# 14         Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Shot
# 15                                                                                                                                   Ball Recovery-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Dispossessed
# 16                                                                                                                                                                                                                                          Block-Ball Recovery-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt
# 17                                                                                                                                                                                                                                                                                                                                      Duel-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Dispossessed
# 18                                                                                                                                                                                                                                                                                                                                                                                      Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt
# 19                                                                                                                                                                                                                                                                                                                                                        Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                       Pass-Ball Receipt-Carry-Miscontrol
# 21                                                                                                                                                                                                                                                                                                              Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt
# 22                                                                                                                                                                                                                                                                                                                                          Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Miscontrol-Pressure
# 23                                                                                                                                                                                                                             Goal Keeper-Pass-Ball Receipt-Pass-Ball Receipt-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Foul Won
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                             Pass-Ball Receipt-Miscontrol
# 25                                                                                                                                                                                                               Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Shot
# 26                                                                                                                                                                                                                                                                                         Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Foul Won
# 27                                                                                                                                                                                                                                        Pass-Ball Recovery-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Foul Won
# 28  Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Ball Recovery-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Duel-Ball Recovery-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Foul Won
# 29                                                                                                                                                                                                                        Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Dribble
# 30                                                                                                                                                                                                                                                                                                                                                                                                                                      Pass-Ball Receipt-Pass-Ball Receipt
# 31                                                                                                                                                                                                                                                                                                                                                                                          Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Ball Recovery
# 32                                                                                                                                                                                                                                                                                                                                                                                            Goal Keeper-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt
# 33                                                                                                                                                                                                                                                                                                                                                                           Pass-Ball Receipt-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Miscontrol
# 34                                                                                                                                                                                                                                                                                                                                                                                                                                         Pass-Ball Receipt-Carry-Foul Won
# 35                                                                                                                                                                                                                                                                                                                                                                                                                                    Pass-Ball Receipt-Miscontrol-Pressure
# 36                                                                                                                                                                                                                                                                                                                                          Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Ball Recovery-Carry-Pass-Ball Receipt
# 37                                                                                                                                                                                                                                                                                                                                Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt
# 38                                                                                                                                                                                                                                                                                                                                               Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Pressure-Ball Receipt
# 39                                                                                                                                                                                                                                                                                       Ball Recovery-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Pressure-Ball Receipt
# 40                                                                                                                                                                                                                                                                                                                                                                                                                                         Pass-Ball Receipt-Carry-Foul Won
# 41                                                                                                                                                                                                                                                                                                                                                                             Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Foul Won-Ball Receipt-Carry-Pass-Ball Receipt
# 42                                                                                                                                                                                                                                                                                                                                                                                                                                                            Pass-Pressure
# 43                                                                                                                                                                                                                                                                                                                                                                                                                               Duel-Ball Recovery-Carry-Pass-Ball Receipt
# 44                                                                                                                                                                                                                                                                                                                                                                                                                                                   Pass-Ball Receipt-Shot
# 45                                                                                                                                                                                                                                                                                                                                                                                      Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt
# 46                                                                                                                                                                                                                                                                                                                                                                                                                                           Ball Recovery-Carry-Miscontrol
# 47                                                                                                                                                                                                                                                                                                                                Ball Recovery-Carry-Dispossessed-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Foul Won
# 48                                                                                                                                                                                                                                                                                                                                                                                                                                                        Pass-Ball Receipt
# 49                                                                                                                                                                                                                                                                                                                                                                                                                   Ball Recovery-Carry-Pass-Ball Receipt-Carry-Miscontrol
# 50                                                                                                                                                                                                                                                                                                                                                                                                   Clearance-Ball Recovery-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Shot
# 51                                                                                                                                                                                                                                   Interception-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Dribble-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Pass-Ball Receipt
# 52                                                                                                                                                                                                                                                                                                                                            Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Pass-Ball Receipt
# 53                                                                                                                                                                                                               Ball Recovery-Carry-Dispossessed-Ball Recovery-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt
# 54                                                                                                                                                                                                                                                   Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Miscontrol
# 55                                                                                                                                                                                                                                                                                                                                                                                                                Duel-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Shot
# 56                                                                                                                                                                                                                                                                                                                                                                                                             Pass-Ball Receipt-Duel-Ball Recovery-Carry-Pass-Ball Receipt
# 57                                                                                                                                                                                                                                                                                                                                                                                       Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Miscontrol
# 58                                                                                                                                                                                                                                                                                                                                                                                          Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Dribble
# 59                                                                                                                                                                                                                                                                                                                                                                              Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Miscontrol-Foul Committed
# 60                                                                                                                                                                                                                                                                                                                                                                            Block-Goal Keeper-Clearance-Clearance-Ball Recovery-Carry-Pass-Ball Receipt-Pass-Ball Receipt
# 61                                                                                                                                                                                                                                                                                                                                                                                                                  Block-Goal Keeper-Ball Recovery-Carry-Pass-Ball Receipt
# 62                                                                                                                                                                                                                                                                                                                                                                                                            Ball Recovery-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt
# 63                                                                                                                                                                                                                                                                                                                                                            Duel-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Pass-Ball Receipt-Pass-Injury Stoppage
# 64                                                                                                                                                                                    Ball Recovery-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt
# 65                                          Ball Recovery-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt
# 66                                                                                                                                                                                                                                                                    Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt
# 67                                                                                                                                                                                                                                                                                                                                                                                            Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Pass-Ball Receipt
# 68                                                                                                                                                                                                                                                                                                                                                                                            Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Pass-Ball Receipt
# 69                                                                                                                                                                                                                                                                                                                                                  Goal Keeper-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt
# 70                                                                                                                                                                                                                                                               Pass-Ball Receipt-Pass-Ball Receipt-Ball Recovery-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Foul Won
# 71                                                                                                                                                                                                                                                                                                                                                                                                                                                        Pass-Ball Receipt
# 72                                                                                                                                                                                                                                                                                                                                                  Pass-Ball Receipt-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt
# 73                                                                                                                                                                                                                                                                                                                                                                         Ball Recovery-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Miscontrol
# 74                                                                                                                                                                                      Goal Keeper-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt
# 75                                                                                                                                                                                                                                                                                                                                                                                                                                Pass-Ball Receipt-Carry-Pass-Ball Receipt
# 76                                                                                                                                                                                                                                                                                                                                                                                                                                    Pass-Ball Receipt-Miscontrol-Pressure
# 77                                                                                                                                                                                                                                                                                                                                       Duel-Ball Recovery-Carry-Dispossessed-Foul Won-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Shot-Substitution
# 78                                                                                                                                                                                                                                                                                                                                                                              Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Offside
# 79              Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt
# 80                                                                                                                                                                                                                                                                                                                                                                                                                     Ball Recovery-Carry-Pass-Ball Receipt-Carry-Foul Won
# 81                                                                                                                                                                                                                Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Shot
# 82                                                                                                                                                                                                                                                                                                                                                                                                                                                   Pass-Ball Receipt-Shot
# 83                                                                                                                                                                                                                                                                                                                                                                                                                                            Pass-Ball Recovery-Carry-Pass
# 84                                                                                                                                                                                                                                                                                                                                                                                    Ball Recovery-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt
# 85                                                                                                                                                                                                                                                                                                                                                                                                                                                        Pass-Ball Receipt
# 86                                                                                                                                                                                                                                                                                                                                                                                                                 Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Foul Won
# 87                                                                                                                                                                                                                                                                                                                                                                                                                                                        Pass-Ball Receipt
# 88                                                                                                                                                                                                                                                                                                                                                                                                                                              Ball Recovery-Carry-Dribble
# 89                                                                                                                                                                                                                                                                                                                                                                                                         Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Miscontrol-50/50
# 90                                                                                                                                                                                                                                                                                                                                                                    Duel-Ball Recovery-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Shot
# 91                               Duel-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Dribble-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Pass-Ball Receipt-Pass-Ball Receipt-Pass-Ball Receipt
# 92                                                                                                                                                                                                                                                                                                                                                                                                           Ball Recovery-Carry-Dribble-Carry-Pass-Ball Receipt-Carry-Shot
# 93                                                                                                                                                                                                                                                                                                                                                                                                            Ball Recovery-Carry-Pass-Ball Receipt-Carry-Pass-Ball Receipt
# 94                                                                                                                                                                                                                                                                                                                                                                                                                                     Pass-Ball Receipt-Carry-Dispossessed
# 95                                                                                                                                                                                                                                                                                                                                                                                                             Clearance-Pass-Ball Receipt-Carry-Pass-Pressure-Ball Receipt
# 96                                                                                                                                                                                                                                                                                                                                                                                                                  Duel-Pass-Ball Receipt-Pass-Ball Receipt-Carry-Foul Won
# 97                                                                                                                                                                                                                                                                                                                                                                                                                                                        Pass-Ball Receipt
#
#     possession  \
# 0            2
# 1            3
# 2            6
# 3            7
# 4            9
# 5           12
# 6           14
# 7           15
# 8           17
# 9           20
# 10          22
# 11          24
# 12          25
# 13          27
# 14          28
# 15          30
# 16          33
# 17          35
# 18          37
# 19          39
# 20          41
# 21          43
# 22          46
# 23          48
# 24          49
# 25          51
# 26          53
# 27          54
# 28          55
# 29          56
# 30          58
# 31          60
# 32          62
# 33          65
# 34          67
# 35          68
# 36          70
# 37          72
# 38          74
# 39          76
# 40          77
# 41          78
# 42          79
# 43          81
# 44          82
# 45          83
# 46          85
# 47          87
# 48          88
# 49          91
# 50          93
# 51          96
# 52          97
# 53          99
# 54         101
# 55         103
# 56         104
# 57         106
# 58         109
# 59         113
# 60         116
# 61         119
# 62         121
# 63         123
# 64         125
# 65         127
# 66         129
# 67         130
# 68         132
# 69         134
# 70         135
# 71         136
# 72         141
# 73         143
# 74         146
# 75         150
# 76         153
# 77         155
# 78         157
# 79         159
# 80         161
# 81         162
# 82         163
# 83         164
# 84         167
# 85         168
# 86         169
# 87         170
# 88         172
# 89         173
# 90         175
# 91         177
# 92         179
# 93         181
# 94         182
# 95         185
# 96         187
# 97         188
#
# ...
# 87                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Leandro Daniel Paredes-Eldor Shomurodov
# 88                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Stephan El Shaarawy-Stephan El Shaarawy-Stephan El Shaarawy
# 89                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Mile Svilar-Mehmet Zeki Çelik-Mehmet Zeki Çelik-Mehmet Zeki Çelik-Stephan El Shaarawy-Stephan El Shaarawy-Stephan El Shaarawy-Stephan El Shaarawy
# 90                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Stephan El Shaarawy-Paulo Bruno Exequiel Dybala-Paulo Bruno Exequiel Dybala-Paulo Bruno Exequiel Dybala-Stephan El Shaarawy-Stephan El Shaarawy-Stephan El Shaarawy-Paulo Bruno Exequiel Dybala-Paulo Bruno Exequiel Dybala-Paulo Bruno Exequiel Dybala-Lorenzo Pellegrini-Lorenzo Pellegrini-Lorenzo Pellegrini
# 91                                                                                                                                               José Ángel Esmoris Tasende-José Ángel Esmoris Tasende-José Ángel Esmoris Tasende-Obite Evan Ndicka-Obite Evan Ndicka-Obite Evan Ndicka-Lorenzo Pellegrini-Lorenzo Pellegrini-Lorenzo Pellegrini-Leandro Daniel Paredes-Leandro Daniel Paredes-Leandro Daniel Paredes-Gianluca Mancini-Gianluca Mancini-Gianluca Mancini-Mehmet Zeki Çelik-Mehmet Zeki Çelik-Mehmet Zeki Çelik-Stephan El Shaarawy-Stephan El Shaarawy-Stephan El Shaarawy-Stephan El Shaarawy-Stephan El Shaarawy-Mehmet Zeki Çelik-Mehmet Zeki Çelik-Mehmet Zeki Çelik-Paulo Bruno Exequiel Dybala-Paulo Bruno Exequiel Dybala-Paulo Bruno Exequiel Dybala-Stephan El Shaarawy-Stephan El Shaarawy-Stephan El Shaarawy-Mehmet Zeki Çelik-Mehmet Zeki Çelik-Mehmet Zeki Çelik-Gianluca Mancini-Gianluca Mancini-Gianluca Mancini-Obite Evan Ndicka-Obite Evan Ndicka-Leandro Daniel Paredes-Leandro Daniel Paredes-Leandro Daniel Paredes-Niccolò Pisilli-Niccolò Pisilli-Obite Evan Ndicka-Obite Evan Ndicka-Obite Evan Ndicka-Niccolò Pisilli-Niccolò Pisilli-José Ángel Esmoris Tasende-José Ángel Esmoris Tasende-Eldor Shomurodov
# 92                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Leandro Daniel Paredes-Leandro Daniel Paredes-Leandro Daniel Paredes-Leandro Daniel Paredes-Leandro Daniel Paredes-Paulo Bruno Exequiel Dybala-Paulo Bruno Exequiel Dybala-Paulo Bruno Exequiel Dybala
# 93                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Lorenzo Pellegrini-Lorenzo Pellegrini-Lorenzo Pellegrini-Obite Evan Ndicka-Obite Evan Ndicka-Obite Evan Ndicka-José Ángel Esmoris Tasende
# 94                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        José Ángel Esmoris Tasende-Eldor Shomurodov-Eldor Shomurodov-Eldor Shomurodov
# 95                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Obite Evan Ndicka-Leandro Daniel Paredes-Paulo Bruno Exequiel Dybala-Paulo Bruno Exequiel Dybala-Paulo Bruno Exequiel Dybala-Eldor Shomurodov-Eldor Shomurodov
# 96                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Eldor Shomurodov-Niccolò Pisilli-Paulo Bruno Exequiel Dybala-Paulo Bruno Exequiel Dybala-Eldor Shomurodov-Eldor Shomurodov-Eldor Shomurodov
# 97                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Gianluca Mancini-Leandro Daniel Paredes
#
#    match_id team_name
# 0   3945135   AS Roma
# 1   3945135   AS Roma
# 2   3945135   AS Roma
# 3   3945135   AS Roma
# 4   3945135   AS Roma
# 5   3945135   AS Roma
# 6   3945135   AS Roma
# 7   3945135   AS Roma
# 8   3945135   AS Roma
# 9   3945135   AS Roma
# 10  3945135   AS Roma
# 11  3945135   AS Roma
# 12  3945135   AS Roma
# 13  3945135   AS Roma
# 14  3945135   AS Roma
# 15  3945135   AS Roma
# 16  3945135   AS Roma
# 17  3945135   AS Roma
# 18  3945135   AS Roma
# 19  3945135   AS Roma
# 20  3945135   AS Roma
# 21  3945135   AS Roma
# 22  3945135   AS Roma
# 23  3945135   AS Roma
# 24  3945135   AS Roma
# 25  3945135   AS Roma
# 26  3945135   AS Roma
# 27  3945135   AS Roma
# 28  3945135   AS Roma
# 29  3945135   AS Roma
# 30  3945135   AS Roma
# 31  3945135   AS Roma
# 32  3945135   AS Roma
# 33  3945135   AS Roma
# 34  3945135   AS Roma
# 35  3945135   AS Roma
# 36  3945135   AS Roma
# 37  3945135   AS Roma
# 38  3945135   AS Roma
# 39  3945135   AS Roma
# 40  3945135   AS Roma
# 41  3945135   AS Roma
# 42  3945135   AS Roma
# 43  3945135   AS Roma
# 44  3945135   AS Roma
# 45  3945135   AS Roma
# 46  3945135   AS Roma
# 47  3945135   AS Roma
# 48  3945135   AS Roma
# 49  3945135   AS Roma
# 50  3945135   AS Roma
# 51  3945135   AS Roma
# 52  3945135   AS Roma
# 53  3945135   AS Roma
# 54  3945135   AS Roma
# 55  3945135   AS Roma
# 56  3945135   AS Roma
# 57  3945135   AS Roma
# 58  3945135   AS Roma
# 59  3945135   AS Roma
# 60  3945135   AS Roma
# 61  3945135   AS Roma
# 62  3945135   AS Roma
# 63  3945135   AS Roma
# 64  3945135   AS Roma
# 65  3945135   AS Roma
# 66  3945135   AS Roma
# 67  3945135   AS Roma
# 68  3945135   AS Roma
# 69  3945135   AS Roma
# 70  3945135   AS Roma
# 71  3945135   AS Roma
# 72  3945135   AS Roma
# 73  3945135   AS Roma
# 74  3945135   AS Roma
# 75  3945135   AS Roma
# 76  3945135   AS Roma
# 77  3945135   AS Roma
# 78  3945135   AS Roma
# 79  3945135   AS Roma
# 80  3945135   AS Roma
# 81  3945135   AS Roma
# 82  3945135   AS Roma
# 83  3945135   AS Roma
# 84  3945135   AS Roma
# 85  3945135   AS Roma
# 86  3945135   AS Roma
# 87  3945135   AS Roma
# 88  3945135   AS Roma
# 89  3945135   AS Roma
# 90  3945135   AS Roma
# 91  3945135   AS Roma
# 92  3945135   AS Roma
# 93  3945135   AS Roma
# 94  3945135   AS Roma
# 95  3945135   AS Roma
# 96  3945135   AS Roma
# 97  3945135   AS Roma

# %%
SKIP_TYPES = {"Half End", "Half Start", "Referee Ball Drop", "Starting XI"}

INPUT_DIR  = Path.home() / "Desktop" / "Podemi_and_Football-main" / "Bundesliga_24_25_matches"
OUTPUT_DIR = Path.home() / "Desktop" / "Podemi_and_Football-main" / "Linguistic" / "Bundesliga_24_25_possession_texts"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

WORDS_COL = "words"

# ----------------------------
# Helpers
# ----------------------------
def safe_key(s: str) -> str:
    return re.sub(r"\W+", "_", (s or "").strip()).strip("_")

def parse_match_id_from_filename(path: str) -> str:
    # prova prima pattern ..._12345.json
    m = re.search(r"_([0-9]+)\.json$", os.path.basename(str(path)))
    if m:
        return m.group(1)
    # fallback: prendi cifre più lunghe nel nome
    m2 = re.search(r"([0-9]{5,})", os.path.basename(str(path)))
    return m2.group(1) if m2 else "unknown"

def norm_type_name(tname: str) -> str:
    return "Ball Receipt" if tname == "Ball Receipt*" else tname

# ----------------------------
# Core logic
# ----------------------------
def build_possession_sequences(events):
    """
    Build sequences segmented by ev["possession"] (the integer).
    Keep ONLY events where team.id == possession_team.id.
    """
    sequences = {}
    id_to_name = {}

    current_possession = None
    current_team_id = None
    buffer_words, buffer_players = [], []

    def flush_run():
        nonlocal buffer_words, buffer_players, current_possession, current_team_id
        if not buffer_words or current_team_id is None or current_possession is None:
            return
        sequences.setdefault(current_team_id, []).append({
            "words": buffer_words[:],
            "players": buffer_players[:],
            "possession": int(current_possession),
        })
        buffer_words, buffer_players = [], []

    for ev in events:
        poss_num = ev.get("possession")
        if poss_num is None:
            continue

        poss_team = ev.get("possession_team") or {}
        team = ev.get("team") or {}

        poss_team_id = poss_team.get("id")
        poss_team_name = poss_team.get("name")
        team_id = team.get("id")
        team_name = team.get("name")

        if poss_team_id is None or poss_team_name is None or team_id is None or team_name is None:
            continue

        # FILTER: keep only events attributed to the team in possession
        if team_id != poss_team_id:
            continue

        id_to_name[poss_team_id] = poss_team_name

        t = ev.get("type")
        tname = t.get("name") if isinstance(t, dict) else None
        if not tname:
            continue
        tname = norm_type_name(tname)

        if tname in SKIP_TYPES:
            continue

        player_name = (ev.get("player") or {}).get("name") or "Unknown"

        # start
        if current_possession is None:
            current_possession = poss_num
            current_team_id = poss_team_id
            buffer_words.append(tname)
            buffer_players.append(player_name)
            continue

        # possession (or team) switch
        if poss_num != current_possession or poss_team_id != current_team_id:
            flush_run()
            current_possession = poss_num
            current_team_id = poss_team_id

        buffer_words.append(tname)
        buffer_players.append(player_name)

    flush_run()
    return sequences, id_to_name

def runs_to_df(runs, match_id, team_name):
    rows = []
    for run in runs:
        words = run["words"]
        players = run["players"]
        poss_num = run["possession"]

        if not words:
            continue

        if len(players) < len(words):
            players = players + ["Unknown"] * (len(words) - len(players))

        rows.append({
            "words": "-".join(words),
            "possession": poss_num,
            "word_players": "-".join(players),
            "match_id": match_id,
            "team_name": team_name,
        })

    return pd.DataFrame(rows, columns=["words", "possession", "word_players", "match_id", "team_name"])

def process_match_file(path: Path):
    with open(path, "r", encoding="utf-8") as f:
        data = json.load(f)

    events = data if isinstance(data, list) else data.get("events", [])
    if not events:
        return None, None

    sequences, id_to_name = build_possession_sequences(events)
    match_id = parse_match_id_from_filename(str(path))

    dfs = []
    for team_id, runs in sequences.items():
        team_name = id_to_name.get(team_id, f"Team{team_id}")
        dfs.append(runs_to_df(runs, match_id, team_name))

    if len(dfs) == 2:
        return dfs[0], dfs[1]
    elif len(dfs) == 1:
        return dfs[0], None
    else:
        return None, None

# ----------------------------
# Save helper
# ----------------------------
def save_team_df(df: pd.DataFrame) -> bool:
    """Salva df in OUTPUT_DIR come TEAM_MATCHID.csv"""
    if df is None or df.empty:
        return False

    team_name = str(df.iloc[0]["team_name"])
    match_id  = str(df.iloc[0]["match_id"])

    out_name = f"{safe_key(team_name)}_{match_id}.csv"
    out_path = OUTPUT_DIR / out_name

    df.to_csv(out_path, index=False, encoding="utf-8")
    return True

# ----------------------------
# RUN batch
# ----------------------------
json_files = sorted(INPUT_DIR.glob("*.json"))

print("CWD (notebook):", Path.cwd())
print("INPUT_DIR:", INPUT_DIR, "exists:", INPUT_DIR.exists())
print("OUTPUT_DIR:", OUTPUT_DIR, "exists:", OUTPUT_DIR.exists())
print("Found JSON files:", len(json_files))

processed = saved = skipped = 0

for path in tqdm(json_files, desc="Processing matches", unit="file"):
    try:
        df1, df2 = process_match_file(path)
        processed += 1

        ok1 = save_team_df(df1)
        ok2 = save_team_df(df2)
        
        if ok1: saved += 1
        if ok2: saved += 1
        if not ok1 and not ok2:
            skipped += 1
            tqdm.write(f"⚠️  Nessun DF valido per: {path.name}")

    except Exception as e:
        skipped += 1
        tqdm.write(f"❌ Errore su {path.name}: {e}")

print("\n✅ FATTO")
print(f"JSON processati: {processed}")
print(f"CSV salvati    : {saved}")
print(f"File saltati   : {skipped}")
print("Output in:", OUTPUT_DIR)
# Out:
# CWD (notebook): /Users/lucasantagata/Desktop/Podemi_and_Football-main/Linguistic
# INPUT_DIR: /Users/lucasantagata/Desktop/Podemi_and_Football-main/Bundesliga_24_25_matches exists: True
# OUTPUT_DIR: /Users/lucasantagata/Desktop/Podemi_and_Football-main/Linguistic/Bundesliga_24_25_possession_texts exists: True
# Found JSON files: 306
# Processing matches: 100%|██████████| 306/306 [00:06<00:00, 45.70file/s]
# ✅ FATTO
# JSON processati: 306
# CSV salvati    : 612
# File saltati   : 0
# Output in: /Users/lucasantagata/Desktop/Podemi_and_Football-main/Linguistic/Bundesliga_24_25_possession_texts
